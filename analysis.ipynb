# %%
import pandas as pd
from scipy.stats import ttest_ind

# 定义需要比较的列名
clnames = ['text', 'interviewee_text', 'new_text', 'new_interviewee_text']
probs_columns = ['bert_prob', 'electra_prob', 'albert_prob', 'MentalBert_prob', 'xlnet_prob', 'roberta_prob']

# 定义需要比较的组合
comparisons = [
    ('text', 'interviewee_text'),
    ('new_text', 'new_interviewee_text'),
    ('text', 'new_text'),
    ('interviewee_text', 'new_interviewee_text')
]

# 遍历每个模型的概率列
for pro in probs_columns:
    print(f"**************** Comparing {pro} ****************")
    for comp in comparisons:
        data1 = pd.read_csv(f'NLP_{comp[0]}.csv')[pro]
        data2 = pd.read_csv(f'NLP_{comp[1]}.csv')[pro]
        statistic, p_value = ttest_ind(data1, data2)
        print(f"Comparison: {comp[0]} vs {comp[1]} for {pro}")
        print(f"T-test P-value: {p_value}")
    print("\n")
# Out:
# **************** Comparing bert_prob ****************
# Comparison: text vs interviewee_text for bert_prob
# T-test P-value: 0.4959411176401535
# Comparison: new_text vs new_interviewee_text for bert_prob
# T-test P-value: 0.4934843920481743
# Comparison: text vs new_text for bert_prob
# T-test P-value: 0.1330792187782198
# Comparison: interviewee_text vs new_interviewee_text for bert_prob
# T-test P-value: 0.05499207015042756
#
#
# **************** Comparing electra_prob ****************
# Comparison: text vs interviewee_text for electra_prob
# T-test P-value: 0.6707698057105984
# Comparison: new_text vs new_interviewee_text for electra_prob
# T-test P-value: 0.4676150007765988
# Comparison: text vs new_text for electra_prob
# T-test P-value: 1.7840614691881312e-13
# Comparison: interviewee_text vs new_interviewee_text for electra_prob
# T-test P-value: 0.0118622163512941
#
#
# **************** Comparing albert_prob ****************
# Comparison: text vs interviewee_text for albert_prob
# T-test P-value: 0.8190760781311914
# Comparison: new_text vs new_interviewee_text for albert_prob
# T-test P-value: 0.03345566453346076
# Comparison: text vs new_text for albert_prob
# T-test P-value: 0.19962698071066082
# Comparison: interviewee_text vs new_interviewee_text for albert_prob
# T-test P-value: 0.4716077399034164
#
#
# **************** Comparing MentalBert_prob ****************
# Comparison: text vs interviewee_text for MentalBert_prob
# T-test P-value: 0.035619736165881814
# Comparison: new_text vs new_interviewee_text for MentalBert_prob
# T-test P-value: 0.06369560050827751
# Comparison: text vs new_text for MentalBert_prob
# T-test P-value: 0.5231728753249809
# Comparison: interviewee_text vs new_interviewee_text for MentalBert_prob
# T-test P-value: 0.35208574944342264
#
#
# **************** Comparing xlnet_prob ****************
# Comparison: text vs interviewee_text for xlnet_prob
# T-test P-value: 0.0112409648274696
# Comparison: new_text vs new_interviewee_text for xlnet_prob
# T-test P-value: 0.5999425262154656
# Comparison: text vs new_text for xlnet_prob
# T-test P-value: 0.01679367157607137
# Comparison: interviewee_text vs new_interviewee_text for xlnet_prob
# T-test P-value: 0.4250801793277722
#
#
# **************** Comparing roberta_prob ****************
# Comparison: text vs interviewee_text for roberta_prob
# T-test P-value: 0.40290317803039666
# Comparison: new_text vs new_interviewee_text for roberta_prob
# T-test P-value: 0.01932661482241292
# Comparison: text vs new_text for roberta_prob
# T-test P-value: 0.0022691921451708217
# Comparison: interviewee_text vs new_interviewee_text for roberta_prob
# T-test P-value: 0.016193975868938854

# %%
import pandas as pd
from scipy.stats import ttest_ind, mannwhitneyu, wilcoxon, ks_2samp, levene

# Define the context names and model probability columns
clnames = ['text', 'interviewee_text', 'new_text', 'new_interviewee_text']
probs_columns = ['bert_prob', 'electra_prob', 'albert_prob', 'MentalBert_prob', 'xlnet_prob', 'roberta_prob']

# Define the comparisons
comparisons = [
    ('text', 'interviewee_text'),
    ('new_text', 'new_interviewee_text'),
    ('text', 'new_text'),
    ('interviewee_text', 'new_interviewee_text')
]

# Iterate through each model's probability column
for pro in probs_columns:
    print(f"**************** Comparing {pro} ****************")
    for comp in comparisons:
        # Dynamically load the CSV files for the two datasets being compared
        data1 = pd.read_csv(f'NLP_{comp[0]}.csv')[pro]
        data2 = pd.read_csv(f'NLP_{comp[1]}.csv')[pro]

        print(f"\nComparison: {comp[0]} vs {comp[1]} for {pro}")

        # 1. Perform Independent t-test
        t_statistic, t_p_value = ttest_ind(data1, data2)
        print(f"T-test P-value: {t_p_value}")

        # 2. Perform Mann-Whitney U Test (non-parametric)
        mw_statistic, mw_p_value = mannwhitneyu(data1, data2)
        print(f"Mann-Whitney U Test P-value: {mw_p_value}")

        # 3. Perform Wilcoxon Signed-Rank Test (only for paired data)
        try:
            wilcoxon_statistic, wilcoxon_p_value = wilcoxon(data1, data2)
            print(f"Wilcoxon Signed-Rank Test P-value: {wilcoxon_p_value}")
        except ValueError:
            # Wilcoxon requires paired data of the same length; catch the error
            print("Wilcoxon Signed-Rank Test not applicable (data lengths do not match).")

        # 4. Perform Kolmogorov-Smirnov Test (distribution comparison)
        ks_statistic, ks_p_value = ks_2samp(data1, data2)
        print(f"Kolmogorov-Smirnov Test P-value: {ks_p_value}")

        # 5. Perform Levene's Test (variance equality check)
        levene_statistic, levene_p_value = levene(data1, data2)
        print(f"Levene's Test P-value: {levene_p_value}")

    print("\n")
# Out:
# **************** Comparing bert_prob ****************
#
# Comparison: text vs interviewee_text for bert_prob
# T-test P-value: 0.4959411176401535
# Mann-Whitney U Test P-value: 0.18361300331048092
# Wilcoxon Signed-Rank Test P-value: 0.5241731310573547
# Kolmogorov-Smirnov Test P-value: 4.463605427422681e-17
# Levene's Test P-value: 7.925004740121991e-17
#
# Comparison: new_text vs new_interviewee_text for bert_prob
# T-test P-value: 0.4934843920481743
# Mann-Whitney U Test P-value: 0.0006055099102112348
# Wilcoxon Signed-Rank Test P-value: 0.2072536123179518
# Kolmogorov-Smirnov Test P-value: 9.137175098834087e-26
# Levene's Test P-value: 0.08932704847337526
#
# Comparison: text vs new_text for bert_prob
# T-test P-value: 0.1330792187782198
# Mann-Whitney U Test P-value: 0.000642426786453639
# Wilcoxon Signed-Rank Test P-value: 0.1416498784939603
# Kolmogorov-Smirnov Test P-value: 1.930571292717153e-16
# Levene's Test P-value: 6.667031777990255e-17
#
# Comparison: interviewee_text vs new_interviewee_text for bert_prob
# T-test P-value: 0.05499207015042756
# Mann-Whitney U Test P-value: 0.47268879787937956
# Wilcoxon Signed-Rank Test P-value: 0.3908120356978185
# Kolmogorov-Smirnov Test P-value: 4.039189014221587e-09
# Levene's Test P-value: 0.044185526848161225
#
#
# **************** Comparing electra_prob ****************
#
# Comparison: text vs interviewee_text for electra_prob
# T-test P-value: 0.6707698057105984
# Mann-Whitney U Test P-value: 3.7166982733059636e-11
# Wilcoxon Signed-Rank Test P-value: 0.09501680890097526
# Kolmogorov-Smirnov Test P-value: 8.712097755016087e-48
# Levene's Test P-value: 1.783792393483437e-10
#
# Comparison: new_text vs new_interviewee_text for electra_prob
# T-test P-value: 0.4676150007765988
# Mann-Whitney U Test P-value: 1.2338455269089219e-23
# Wilcoxon Signed-Rank Test P-value: 0.003953198477328087
# Kolmogorov-Smirnov Test P-value: 8.443845440045891e-72
# Levene's Test P-value: 1.538560722028826e-13
#
# Comparison: text vs new_text for electra_prob
# T-test P-value: 1.7840614691881312e-13
# Mann-Whitney U Test P-value: 6.125899159599956e-11
# Wilcoxon Signed-Rank Test P-value: 3.0202701336685637e-12
# Kolmogorov-Smirnov Test P-value: 1.0009765236354853e-17
# Levene's Test P-value: 3.5565561897310287e-09
#
# Comparison: interviewee_text vs new_interviewee_text for electra_prob
# T-test P-value: 0.0118622163512941
# Mann-Whitney U Test P-value: 0.24962944748888105
# Wilcoxon Signed-Rank Test P-value: 0.009326891380396165
# Kolmogorov-Smirnov Test P-value: 0.015903160012587927
# Levene's Test P-value: 0.005453000281930934
#
#
# **************** Comparing albert_prob ****************
#
# Comparison: text vs interviewee_text for albert_prob
# T-test P-value: 0.8190760781311914
# Mann-Whitney U Test P-value: 1.81384199860881e-05
# Wilcoxon Signed-Rank Test P-value: 0.47867329628219
# Kolmogorov-Smirnov Test P-value: 3.1211581794993975e-32
# Levene's Test P-value: 1.5068216443211722e-15
#
# Comparison: new_text vs new_interviewee_text for albert_prob
# T-test P-value: 0.03345566453346076
# Mann-Whitney U Test P-value: 0.15667538799790534
# Wilcoxon Signed-Rank Test P-value: 0.03668758317177938
# Kolmogorov-Smirnov Test P-value: 0.001214956950276088
# Levene's Test P-value: 2.305353044409459e-09
#
# Comparison: text vs new_text for albert_prob
# T-test P-value: 0.19962698071066082
# Mann-Whitney U Test P-value: 0.13918685126219812
# Wilcoxon Signed-Rank Test P-value: 0.13647249315425836
# Kolmogorov-Smirnov Test P-value: 4.652113090537595e-10
# Levene's Test P-value: 0.009375500468589414
#
# Comparison: interviewee_text vs new_interviewee_text for albert_prob
# T-test P-value: 0.4716077399034164
# Mann-Whitney U Test P-value: 6.73791820764141e-05
# Wilcoxon Signed-Rank Test P-value: 0.7211723930315914
# Kolmogorov-Smirnov Test P-value: 1.259995882579524e-33
# Levene's Test P-value: 2.0062234554415407e-23
#
#
# **************** Comparing MentalBert_prob ****************
#
# Comparison: text vs interviewee_text for MentalBert_prob
# T-test P-value: 0.035619736165881814
# Mann-Whitney U Test P-value: 1.0299730026423546e-08
# Wilcoxon Signed-Rank Test P-value: 2.583454131125199e-07
# Kolmogorov-Smirnov Test P-value: 1.2621550403839358e-12
# Levene's Test P-value: 0.03613577963282978
#
# Comparison: new_text vs new_interviewee_text for MentalBert_prob
# T-test P-value: 0.06369560050827751
# Mann-Whitney U Test P-value: 0.005020762843707568
# Wilcoxon Signed-Rank Test P-value: 0.00015259881243993536
# Kolmogorov-Smirnov Test P-value: 0.00045587000221231896
# Levene's Test P-value: 0.06489907705902546
#
# Comparison: text vs new_text for MentalBert_prob
# T-test P-value: 0.5231728753249809
# Mann-Whitney U Test P-value: 1.6662702183981e-07
# Wilcoxon Signed-Rank Test P-value: 0.11457815087651742
# Kolmogorov-Smirnov Test P-value: 4.1927602968380604e-20
# Levene's Test P-value: 0.5132776372620309
#
# Comparison: interviewee_text vs new_interviewee_text for MentalBert_prob
# T-test P-value: 0.35208574944342264
# Mann-Whitney U Test P-value: 0.08725287392091226
# Wilcoxon Signed-Rank Test P-value: 0.8741447298752639
# Kolmogorov-Smirnov Test P-value: 2.067856572632497e-06
# Levene's Test P-value: 0.33977464912692823
#
#
# **************** Comparing xlnet_prob ****************
#
# Comparison: text vs interviewee_text for xlnet_prob
# T-test P-value: 0.0112409648274696
# Mann-Whitney U Test P-value: 0.003255696384402505
# Wilcoxon Signed-Rank Test P-value: 8.911496501347922e-05
# Kolmogorov-Smirnov Test P-value: 4.858198540787849e-06
# Levene's Test P-value: 0.511591712478213
#
# Comparison: new_text vs new_interviewee_text for xlnet_prob
# T-test P-value: 0.5999425262154656
# Mann-Whitney U Test P-value: 0.14215734133350708
# Wilcoxon Signed-Rank Test P-value: 0.06706390524588629
# Kolmogorov-Smirnov Test P-value: 1.2621550403839358e-12
# Levene's Test P-value: 4.104249978234734e-09
#
# Comparison: text vs new_text for xlnet_prob
# T-test P-value: 0.01679367157607137
# Mann-Whitney U Test P-value: 0.5339314647200673
# Wilcoxon Signed-Rank Test P-value: 0.13788592768265667
# Kolmogorov-Smirnov Test P-value: 0.009418484649599148
# Levene's Test P-value: 0.03482670587443661
#
# Comparison: interviewee_text vs new_interviewee_text for xlnet_prob
# T-test P-value: 0.4250801793277722
# Mann-Whitney U Test P-value: 9.70982074158417e-05
# Wilcoxon Signed-Rank Test P-value: 0.02770032652195799
# Kolmogorov-Smirnov Test P-value: 1.0009765236354853e-17
# Levene's Test P-value: 3.4380408415375397e-13
#
#
# **************** Comparing roberta_prob ****************
#
# Comparison: text vs interviewee_text for roberta_prob
# T-test P-value: 0.40290317803039666
# Mann-Whitney U Test P-value: 0.11235366621889656
# Wilcoxon Signed-Rank Test P-value: 0.1205310185541748
# Kolmogorov-Smirnov Test P-value: 8.558741000230393e-07
# Levene's Test P-value: 2.0430828303510347e-10
#
# Comparison: new_text vs new_interviewee_text for roberta_prob
# T-test P-value: 0.01932661482241292
# Mann-Whitney U Test P-value: 0.16371912343568773
# Wilcoxon Signed-Rank Test P-value: 0.03680801908808322
# Kolmogorov-Smirnov Test P-value: 0.00032431894443258567
# Levene's Test P-value: 0.03540508379880852
#
# Comparison: text vs new_text for roberta_prob
# T-test P-value: 0.0022691921451708217
# Mann-Whitney U Test P-value: 0.248269220780853
# Wilcoxon Signed-Rank Test P-value: 0.004476959757028012
# Kolmogorov-Smirnov Test P-value: 1.3025987517793812e-14
# Levene's Test P-value: 1.4298562227367778e-29
#
# Comparison: interviewee_text vs new_interviewee_text for roberta_prob
# T-test P-value: 0.016193975868938854
# Mann-Whitney U Test P-value: 0.008620152957292232
# Wilcoxon Signed-Rank Test P-value: 0.010905934911583624
# Kolmogorov-Smirnov Test P-value: 5.330351753104102e-05
# Levene's Test P-value: 0.0038259367348526777

# %%
import pandas as pd
from sklearn.metrics import roc_auc_score, f1_score
from scipy.stats import ttest_ind

# Define column names for models and probabilities
probs_columns = ['bert_prob', 'electra_prob', 'albert_prob', 'MentalBert_prob', 'xlnet_prob', 'roberta_prob']

# Define comparisons
comparisons = [
    ('text', 'interviewee_text'),
    ('new_text', 'new_interviewee_text'),
    ('text', 'new_text'),
    ('interviewee_text', 'new_interviewee_text')
]

# Iterate over each model's probability column
for pro in probs_columns:
    print(f"**************** Comparing {pro} ****************")
    for comp in comparisons:
        # Load datasets
        data1 = pd.read_csv(f'NLP_{comp[0]}.csv')
        data2 = pd.read_csv(f'NLP_{comp[1]}.csv')
        
        # Perform T-test on probabilities
        statistic, p_value = ttest_ind(data1[pro], data2[pro])
        print(f"Comparison: {comp[0]} vs {comp[1]} for {pro}")
        print(f"T-test P-value: {p_value}")
        
        # Calculate AUC for each dataset
        auc1 = roc_auc_score(data1['true_labels'], data1[pro])
        auc2 = roc_auc_score(data2['true_labels'], data2[pro])
        
        print(f"AUC for {comp[0]} ({pro}): {auc1}")
        print(f"AUC for {comp[1]} ({pro}): {auc2}")
        
        # Calculate F1-score for each dataset (using a threshold of 0.5)
        preds1 = (data1[pro] >= 0.5).astype(int)  # Convert probabilities to class predictions
        preds2 = (data2[pro] >= 0.5).astype(int)
        
        f1_1 = f1_score(data1['true_labels'], preds1)
        f1_2 = f1_score(data2['true_labels'], preds2)
        
        print(f"F1-score for {comp[0]} ({pro}): {f1_1}")
        print(f"F1-score for {comp[1]} ({pro}): {f1_2}")
        
    print("\n")
# Out:
# **************** Comparing bert_prob ****************
# Comparison: text vs interviewee_text for bert_prob
# T-test P-value: 0.4959411176401535
# AUC for text (bert_prob): 0.7185417672621922
# AUC for interviewee_text (bert_prob): 0.6070014485755673
# F1-score for text (bert_prob): 0.7673267326732673
# F1-score for interviewee_text (bert_prob): 0.7641509433962265
# Comparison: new_text vs new_interviewee_text for bert_prob
# T-test P-value: 0.4934843920481743
# AUC for new_text (bert_prob): 0.5303718010622888
# AUC for new_interviewee_text (bert_prob): 0.6248913568324481
# F1-score for new_text (bert_prob): 0.7129629629629629
# F1-score for new_interviewee_text (bert_prob): 0.7628361858190709
# Comparison: text vs new_text for bert_prob
# T-test P-value: 0.1330792187782198
# AUC for text (bert_prob): 0.7185417672621922
# AUC for new_text (bert_prob): 0.5303718010622888
# F1-score for text (bert_prob): 0.7673267326732673
# F1-score for new_text (bert_prob): 0.7129629629629629
# Comparison: interviewee_text vs new_interviewee_text for bert_prob
# T-test P-value: 0.05499207015042756
# AUC for interviewee_text (bert_prob): 0.6070014485755673
# AUC for new_interviewee_text (bert_prob): 0.6248913568324481
# F1-score for interviewee_text (bert_prob): 0.7641509433962265
# F1-score for new_interviewee_text (bert_prob): 0.7628361858190709
#
#
# **************** Comparing electra_prob ****************
# Comparison: text vs interviewee_text for electra_prob
# T-test P-value: 0.6707698057105984
# AUC for text (electra_prob): 0.5863833896668276
# AUC for interviewee_text (electra_prob): 0.6448092708836312
# F1-score for text (electra_prob): 0.7477876106194691
# F1-score for interviewee_text (electra_prob): 0.7418546365914787
# Comparison: new_text vs new_interviewee_text for electra_prob
# T-test P-value: 0.4676150007765988
# AUC for new_text (electra_prob): 0.4975857073877354
# AUC for new_interviewee_text (electra_prob): 0.6247223563495896
# F1-score for new_text (electra_prob): 0.7720739219712526
# F1-score for new_interviewee_text (electra_prob): 0.7710280373831776
# Comparison: text vs new_text for electra_prob
# T-test P-value: 1.7840614691881312e-13
# AUC for text (electra_prob): 0.5863833896668276
# AUC for new_text (electra_prob): 0.4975857073877354
# F1-score for text (electra_prob): 0.7477876106194691
# F1-score for new_text (electra_prob): 0.7720739219712526
# Comparison: interviewee_text vs new_interviewee_text for electra_prob
# T-test P-value: 0.0118622163512941
# AUC for interviewee_text (electra_prob): 0.6448092708836312
# AUC for new_interviewee_text (electra_prob): 0.6247223563495896
# F1-score for interviewee_text (electra_prob): 0.7418546365914787
# F1-score for new_interviewee_text (electra_prob): 0.7710280373831776
#
#
# **************** Comparing albert_prob ****************
# Comparison: text vs interviewee_text for albert_prob
# T-test P-value: 0.8190760781311914
# AUC for text (albert_prob): 0.7463544181554804
# AUC for interviewee_text (albert_prob): 0.7957025591501691
# F1-score for text (albert_prob): 0.7972027972027972
# F1-score for interviewee_text (albert_prob): 0.8082901554404145
# Comparison: new_text vs new_interviewee_text for albert_prob
# T-test P-value: 0.03345566453346076
# AUC for new_text (albert_prob): 0.6387252535007244
# AUC for new_interviewee_text (albert_prob): 0.6244809270883631
# F1-score for new_text (albert_prob): 0.7294685990338164
# F1-score for new_interviewee_text (albert_prob): 0.7678571428571429
# Comparison: text vs new_text for albert_prob
# T-test P-value: 0.19962698071066082
# AUC for text (albert_prob): 0.7463544181554804
# AUC for new_text (albert_prob): 0.6387252535007244
# F1-score for text (albert_prob): 0.7972027972027972
# F1-score for new_text (albert_prob): 0.7294685990338164
# Comparison: interviewee_text vs new_interviewee_text for albert_prob
# T-test P-value: 0.4716077399034164
# AUC for interviewee_text (albert_prob): 0.7957025591501691
# AUC for new_interviewee_text (albert_prob): 0.6244809270883631
# F1-score for interviewee_text (albert_prob): 0.8082901554404145
# F1-score for new_interviewee_text (albert_prob): 0.7678571428571429
#
#
# **************** Comparing MentalBert_prob ****************
# Comparison: text vs interviewee_text for MentalBert_prob
# T-test P-value: 0.035619736165881814
# AUC for text (MentalBert_prob): 0.7047078705939159
# AUC for interviewee_text (MentalBert_prob): 0.6345726702076293
# F1-score for text (MentalBert_prob): 0.7562189054726368
# F1-score for interviewee_text (MentalBert_prob): 0.6965699208443272
# Comparison: new_text vs new_interviewee_text for MentalBert_prob
# T-test P-value: 0.06369560050827751
# AUC for new_text (MentalBert_prob): 0.5747223563495896
# AUC for new_interviewee_text (MentalBert_prob): 0.6715113471752776
# F1-score for new_text (MentalBert_prob): 0.7237163814180929
# F1-score for new_interviewee_text (MentalBert_prob): 0.731457800511509
# Comparison: text vs new_text for MentalBert_prob
# T-test P-value: 0.5231728753249809
# AUC for text (MentalBert_prob): 0.7047078705939159
# AUC for new_text (MentalBert_prob): 0.5747223563495896
# F1-score for text (MentalBert_prob): 0.7562189054726368
# F1-score for new_text (MentalBert_prob): 0.7237163814180929
# Comparison: interviewee_text vs new_interviewee_text for MentalBert_prob
# T-test P-value: 0.35208574944342264
# AUC for interviewee_text (MentalBert_prob): 0.6345726702076293
# AUC for new_interviewee_text (MentalBert_prob): 0.6715113471752776
# F1-score for interviewee_text (MentalBert_prob): 0.6965699208443272
# F1-score for new_interviewee_text (MentalBert_prob): 0.731457800511509
#
#
# **************** Comparing xlnet_prob ****************
# Comparison: text vs interviewee_text for xlnet_prob
# T-test P-value: 0.0112409648274696
# AUC for text (xlnet_prob): 0.5745774987928537
# AUC for interviewee_text (xlnet_prob): 0.5557943022694349
# F1-score for text (xlnet_prob): 0.7067307692307693
# F1-score for interviewee_text (xlnet_prob): 0.7511737089201878
# Comparison: new_text vs new_interviewee_text for xlnet_prob
# T-test P-value: 0.5999425262154656
# AUC for new_text (xlnet_prob): 0.49323998068565905
# AUC for new_interviewee_text (xlnet_prob): 0.6338242394978271
# F1-score for new_text (xlnet_prob): 0.724373576309795
# F1-score for new_interviewee_text (xlnet_prob): 0.7632183908045977
# Comparison: text vs new_text for xlnet_prob
# T-test P-value: 0.01679367157607137
# AUC for text (xlnet_prob): 0.5745774987928537
# AUC for new_text (xlnet_prob): 0.49323998068565905
# F1-score for text (xlnet_prob): 0.7067307692307693
# F1-score for new_text (xlnet_prob): 0.724373576309795
# Comparison: interviewee_text vs new_interviewee_text for xlnet_prob
# T-test P-value: 0.4250801793277722
# AUC for interviewee_text (xlnet_prob): 0.5557943022694349
# AUC for new_interviewee_text (xlnet_prob): 0.6338242394978271
# F1-score for interviewee_text (xlnet_prob): 0.7511737089201878
# F1-score for new_interviewee_text (xlnet_prob): 0.7632183908045977
#
#
# **************** Comparing roberta_prob ****************
# Comparison: text vs interviewee_text for roberta_prob
# T-test P-value: 0.40290317803039666
# AUC for text (roberta_prob): 0.6111057460164171
# AUC for interviewee_text (roberta_prob): 0.5734910671173346
# F1-score for text (roberta_prob): 0.6738544474393531
# F1-score for interviewee_text (roberta_prob): 0.6577540106951871
# Comparison: new_text vs new_interviewee_text for roberta_prob
# T-test P-value: 0.01932661482241292
# AUC for new_text (roberta_prob): 0.5730082085948817
# AUC for new_interviewee_text (roberta_prob): 0.66323032351521
# F1-score for new_text (roberta_prob): 0.7672413793103449
# F1-score for new_interviewee_text (roberta_prob): 0.7793427230046949
# Comparison: text vs new_text for roberta_prob
# T-test P-value: 0.0022691921451708217
# AUC for text (roberta_prob): 0.6111057460164171
# AUC for new_text (roberta_prob): 0.5730082085948817
# F1-score for text (roberta_prob): 0.6738544474393531
# F1-score for new_text (roberta_prob): 0.7672413793103449
# Comparison: interviewee_text vs new_interviewee_text for roberta_prob
# T-test P-value: 0.016193975868938854
# AUC for interviewee_text (roberta_prob): 0.5734910671173346
# AUC for new_interviewee_text (roberta_prob): 0.66323032351521
# F1-score for interviewee_text (roberta_prob): 0.6577540106951871
# F1-score for new_interviewee_text (roberta_prob): 0.7793427230046949

# %%
import pandas as pd
from sklearn.metrics import roc_auc_score

# 定义模型概率的列名和文件名部分
probs_columns = ['bert_prob', 'electra_prob', 'albert_prob', 'MentalBert_prob', 'xlnet_prob', 'roberta_prob']
clnames = ['text', 'interviewee_text', 'new_text', 'new_interviewee_text']

# 遍历每个文件名部分，读取数据并计算新概率
for comp in clnames:
    # 读取数据
    df = pd.read_csv(f'NLP_{comp}.csv')
    
    # 根据列名不同计算新概率
    if comp == 'text':
        # Bert, Electra, Albert, MentalBert 的 lower quartiles
        df['prob'] = df[['bert_prob', 'electra_prob', 'albert_prob', 'MentalBert_prob']].quantile(0.25, axis=1)
    elif comp == 'interviewee_text':
        # Bert, Electra, Albert, MentalBert 的均值
        df['prob'] = df[['bert_prob', 'electra_prob', 'albert_prob', 'MentalBert_prob']].mean(axis=1)
    elif comp == 'new_text':
        # Albert, MentalBert 的 upper quartiles
        df['prob'] = df[['albert_prob', 'MentalBert_prob']].quantile(0.75, axis=1)
    elif comp == 'new_interviewee_text':
        # Bert, Electra, Albert, MentalBert, XLNet, RoBERTa 的均值
        df['prob'] = df[probs_columns].mean(axis=1)
    
    # 仅保留新概率列和 true_labels 列
    df = df[['prob', 'true_labels']]
    
    # 计算 AUC
    try:
        auc = roc_auc_score(df['true_labels'], df['prob'])
        print(f"{comp} AUC: {auc:.4f}")
    except ValueError as e:
        print(f"{comp} AUC could not be calculated: {e}")
    
    # 保存处理后的数据
    df.to_csv(f'NLP_{comp}_processed.csv', index=False)
# Out:
# text AUC: 0.7597
# interviewee_text AUC: 0.7593
# new_text AUC: 0.6485
# new_interviewee_text AUC: 0.6804
